# %%
import spacy
from spacy.tokens import Doc

class WhitespaceTokenizer(object):
    def __init__(self, vocab):
        self.vocab = vocab

    def __call__(self, text):
        words = text.split(' ')
        # All tokens 'own' a subsequent space character in this tokenizer
        spaces = [True] * len(words)
        return Doc(self.vocab, words=words, spaces=spaces)

# %%
import benepar
from benepar.spacy_plugin import BeneparComponent
spacy.require_gpu(0)
benepar.download('benepar_en')
nlp = spacy.load('en_core_web_sm',disable=["ner"])
nlp.tokenizer = WhitespaceTokenizer(nlp.vocab)
nlp.add_pipe(BeneparComponent('benepar_en'))

import nltk
from nltk.tree import Tree
from nltk.tree import ParentedTree
# Out:
# [nltk_data] Downloading package benepar_en to
# [nltk_data]     /home/gaurish/nltk_data...
# [nltk_data]   Package benepar_en is already up-to-date!

# %%
import csv
def _read(file_path):
    with open(file_path, 'r') as file:
        reader = csv.reader(file, delimiter=",")
        tokens = []
        tags = []
        for row in reader:
            word, label = row

            if word == '\n':
                continue
            if word == "*START-SENTENCE*":
                tokens = []
                tags = []
            elif word == "*END-SENTENCE*":
                if len(tokens) > 1:
                    yield " ".join(tokens)
                tokens = []
                tags = []
            elif word == "*START-ACTOR*" or word == "*END-ACTOR*":
                continue
            else:
                if label not in {'I-cue', 'I-scope', 'O'}:
                    raise RuntimeError(
                        'Label %s is not a valid tag' % label)
                tokens.append(word)
                tags.append(label)

# %%
train_data = _read('data/unlabelled_conandoyle_train.csv')
train_data_full = _read('data/unlabelled_conandoyle_train_full.csv')
dev_data = _read('data/labelled_conandoyle_dev.csv')
test_data = _read('data/labelled_conandoyle_test.csv')

# %%
train_data =list(train_data)
len((train_data))
# Out:
# 699

# %%
train_data_full =list(train_data_full)
len( (train_data_full))
# Out:
# 842

# %%
dev_data = list(dev_data)
len( (dev_data))
# Out:
# 144

# %%
test_data = list(test_data)
len( (test_data))
# Out:
# 235

# %%
import jsonlines

# %%
dataset = []

for doc in nlp.pipe(train_data, n_threads=8, batch_size=10000):
#     sent = list(doc.sents)[0]
    key = " ".join([token.text for token in doc])
    dataset.append({
        key :{ 
            "parse_string":[sent._.parse_string for sent in doc.sents] ,
            "pos_tags":[token.pos_ for token in doc]
    }
                   })
with jsonlines.open('spacy_features_train.jsonl', 'w') as writer:
    writer.write_all(dataset)

# %%
len(dataset),dataset[0]
# Out:
# (699,
#  {'Mr. Sherlock Holmes , who was usually very late in the mornings , save upon those not infrequent occasions when he was up all night , was seated at the breakfast table .': {'parse_string': ['(S (NP (NP (NNP Mr.) (NNP Sherlock) (NNP Holmes)) (, ,) (SBAR (SBAR (WHNP (WP who)) (S (VP (VBD was) (ADVP (RB usually)) (RB very) (JJ late) (PP (IN in) (NP (DT the) (NNS mornings)))))) (, ,) (VP (VB save) (PP (IN upon) (NP (DT those) (ADJP (RB not) (JJ infrequent)) (NNS occasions))) (SBAR (WHADVP (WRB when)) (S (NP (PRP he)) (VP (VBD was) (ADVP (RB up)) (NP (DT all) (NN night))))))) (, ,)) (VP (VBD was) (VP (VBN seated) (PP (IN at) (NP (DT the) (NN breakfast) (NN table))))) (. .))'],
#    'pos_tags': ['PROPN',
#     'PROPN',
#     'PROPN',
#     'PUNCT',
#     'PRON',
#     'AUX',
#     'ADV',
#     'ADV',
#     'ADJ',
#     'ADP',
#     'DET',
#     'NOUN',
#     'PUNCT',
#     'VERB',
#     'SCONJ',
#     'DET',
#     'PART',
#     'ADJ',
#     'NOUN',
#     'ADV',
#     'PRON',
#     'AUX',
#     'ADV',
#     'DET',
#     'NOUN',
#     'PUNCT',
#     'AUX',
#     'VERB',
#     'ADP',
#     'DET',
#     'NOUN',
#     'NOUN',
#     'PUNCT']}})

# %%
list(dev_data)
# Out:
# ['He made no remark , but the matter remained in his thoughts , for he stood in front of the fire afterwards with a thoughtful face , smoking his pipe , and casting an occasional glance at the message .',
#  'No woman would ever send a reply-paid telegram .',
#  'My mind is like a racing engine , tearing itself to pieces because it is not connected up with the work for which it was built .',
#  "`` I have had a most singular and unpleasant experience , Mr. Holmes , '' said he .",
#  '`` Never in my life have I been placed in such a situation .',
#  'It is most improper -- most outrageous .',
#  '`` Well , sir , it did not appear to be a matter which concerned the police , and yet , when you have heard the facts , you must admit that I could not leave it where it was .',
#  "Private detectives are a class with whom I have absolutely no sympathy , but none the less , having heard your name -- ''",
#  "But , in the second place , why did you not come at once ? ''",
#  "But no one can glance at your toilet and attire without seeing that your disturbance dates from the moment of your waking . ''",
#  'Our client smoothed down his unbrushed hair and felt his unshaven chin .',
#  'I never gave a thought to my toilet .',
#  "Please arrange your thoughts and let me know , in their due sequence , exactly what those events are which have sent you out unbrushed and unkempt , with dress boots and waistcoat buttoned awry , in search of advice and assistance . ''",
#  'Our client looked down with a rueful face at his own unconventional appearance .',
#  "`` I 'm sure it must look very bad , Mr. Holmes , and I am not aware that in my whole life such a thing has ever happened before .",
#  "You do n't mean -- you do n't mean that I am suspected ? ''",
#  'I think , Watson , a brandy and soda would do him no harm .',
#  "Now , sir , I suggest that you take no notice of this addition to your audience , and that you proceed with your narrative exactly as you would have done had you never been interrupted . ''",
#  'He continually drummed his fingers on the table , gnawed his nails , and gave other signs of nervous impatience .',
#  'The dinner itself was neither well served nor well cooked , and the gloomy presence of the taciturn servant did not help to enliven us .',
#  'I thought nothing of it at the time .',
#  'He gave up all pretence at conversation and sat , smoking endless cigarettes , lost in his own thoughts , but he made no remark as to the contents .',
#  'I said that I had not .',
#  'There was no response .',
#  'You can imagine my surprise when I found that there was no one there .',
#  'There was no answer .',
#  'No reply .',
#  'The room was empty , and the bed had never been slept in .',
#  'But this theory would not work .',
#  'The man was unknown there .',
#  'I can assure you that every word I have said is the truth , and that , outside of what I have told you , I know absolutely nothing about the fate of this man .',
#  "I picked this out unburned from the back of it . ''",
#  '`` The note is written upon ordinary cream-laid paper without watermark .',
#  'The oval seal is undoubtedly a plain sleeve-link -- what else is of such a shape ?',
#  "`` I 'm bound to say that I make nothing of the note except that there was something on hand , and that a woman , as usual was at the bottom of it . ''",
#  "`` But I beg to point out that I have not yet heard what has happened to Mr. Garcia , nor what has become of his household . ''",
#  'It is a lonely corner , and there is no house within a quarter of a mile of the spot .',
#  "There are no footsteps nor any clue to the criminals . ''",
#  "`` No , there was no attempt at robbery . ''",
#  "`` This is very painful -- very painful and terrible , '' said Mr. Scott Eccles in a querulous voice , `` but it is really uncommonly hard on me .",
#  'I had nothing to do with my host going off upon a nocturnal excursion and meeting so sad an end .',
#  'It was after nine this morning when we reached his house and found neither you nor anyone else inside it .',
#  "I desire you to spare no expense and no pains to get at the truth . ''",
#  "`` I suppose that you have no objection to my collaborating with you , Mr. Baynes ? ''",
#  "`` But that is perfectly impossible , Mr. Baynes , '' cried our client .",
#  '`` His voice is unmistakable .',
#  "`` Remarkable , but by no means impossible , '' said Holmes , smiling .",
#  '`` On the face of it the case is not a very complex one , though it certainly presents some novel and interesting features .',
#  "`` I can make nothing of this mystification of Scott Eccles . ''",
#  '`` You must admit , my dear Watson , that the idea of a joke is impossible .',
#  'There is , on the face of it , something unnatural about this strange and sudden friendship between the young Spaniard and Scott Eccles .',
#  'I see no charm in the man .',
#  'He is not particularly intelligent -- not a man likely to be congenial to a quick-witted Latin .',
#  "You saw yourself how neither of the inspectors dreamed of questioning his statement , extraordinary as it was . ''",
#  '`` Nothing , as things turned out , but everything had they gone another way .',
#  'By some juggling of the clocks it is quite possible that they may have got Scott Eccles to bed earlier than he thought , but in any case it is likely that when Garcia went out of his way to tell him that it was one it was really not more than twelve .',
#  'Here was this irreproachable Englishman ready to swear in any court of law that the accused was in the house all the time .',
#  '`` I have not all my facts yet , but I do not think there are any insuperable difficulties .',
#  "You find yourself insensibly twisting them round to fit your theories . ''",
#  "She would not have said ` Godspeed ' had it not been so .",
#  '`` Good , Watson , very good -- but quite inadmissable .',
#  "Meanwhile we can thank our lucky fate which has rescued us for a few short hours from the insufferable fatigues of idleness . ''",
#  "`` I do n't quite understand . ''",
#  "It is equally certain that this house can not be more than a mile or two from Oxshott , since Garcia was walking in that direction and hoped , according to my reading of the facts , to be back in Wisteria Lodge in time to avail himself of an alibi , which would only be valid up to one o'clock .",
#  "It has been a long evening , and I do n't think my nerve is as good as it was . ''",
#  "I should not have thought you had a nerve in your body . ''",
#  "I do n't know what made me look up , but there was a face looking in at me through the lower pane .",
#  "This is not talk for a police-constable . ''",
#  "`` I know , sir , I know ; but it shook me , sir , and there 's no use to deny it .",
#  "It was n't black , sir , nor was it white , nor any colour that I know but a kind of queer shade like clay with a splash of milk in it .",
#  "I tell you , sir , I could n't move a finger , nor get my breath , till it whisked away and was gone .",
#  "Out I ran and through the shrubbery , but thank God there was no one there . ''",
#  "`` If I did n't know you were a good man , Walters , I should put a black mark against you for this .",
#  'If it were the devil himself a constable on duty should never thank God that he could not lay his hands upon him .',
#  "I suppose the whole thing is not a vision and a touch of nerves ? ''",
#  'The various bedrooms and sitting-rooms had yielded nothing to a careful search .',
#  'Apparently the tenants had brought little or nothing with them , and all the furniture down to the smallest details had been taken over with the house .',
#  'Telegraphic inquiries had been already made which showed that Marx knew nothing of his customer save that he was a good payer .',
#  "`` Nothing in all this , '' said Baynes , stalking , candle in hand , from room to room .",
#  "He says that they are not human . ''",
#  "Your powers , if I may say so without offence , seem superior to your opportunities . ''",
#  "I should be glad to be able to say afterwards that I had solved it without your help . ''",
#  'After his habit he said nothing , and after mine I asked no questions .',
#  'Sufficient for me to share the sport and lend my humble help to the capture without distracting that intent brain with needless interruption .',
#  'Day succeeded day , and my friend took no step forward .',
#  'Save for this one excursion , he spent his days in long and often solitary walks , or in chatting with a number of village gossips whose acquaintance he had cultivated .',
#  'He said little about the case , but from that little we gathered that he also was not dissatisfied at the course of events .',
#  "`` You do n't mean that Baynes has got him ? ''",
#  'It was suggested , but never proved , that the deceased gentleman may have had valuables in the house , and that their abstraction was the motive of the crime .',
#  'Every effort was made by Inspector Baynes , who has the case in hand , to ascertain the hiding place of the fugitives , and he had good reason to believe that they had not gone far but were lurking in some retreat which had been already prepared .',
#  "Pray do n't think it a liberty if I give you a word of friendly warning . ''",
#  '`` I have looked into this case with some care , and I am not convinced that you are on the right lines .',
#  "I do n't want you to commit yourself too far unless you are sure . ''",
#  "`` Do n't blame me . ''",
#  '`` No , sir ; I believe you mean well by me .',
#  "`` Let us say no more about it . ''",
#  "He hardly speaks a word of English , and we can get nothing out of him but grunts . ''",
#  "`` I did n't say so , Mr. Holmes ; I did n't say so .",
#  "`` I ca n't make the man out .",
#  "But there 's something in Inspector Baynes which I ca n't quite understand . ''",
#  'They were all confederates in the same unknown crime .',
#  'But the attempt was a dangerous one , and if Garcia did not return by a certain hour it was probable that his own life had been sacrificed .',
#  'The whole inexplicable tangle seemed to straighten out before me .',
#  'I wondered , as I always did , how it had not been obvious to me before .',
#  '`` We can imagine that in the confusion of flight something precious , something which he could not bear to part with , had been left behind .',
#  'He is either a foreigner or has lived long in the tropics , for he is yellow and sapless , but tough as whipcord .',
#  'His friend and secretary , Mr. Lucas , is undoubtedly a foreigner , chocolate brown , wily , suave , and catlike , with a poisonous gentleness of speech .',
#  'There are no better instruments than discharged servants with a grievance , and I was lucky enough to find one .',
#  'I call it luck , but it would not have come my way had I not been looking out for it .',
#  'He in turn had friends among the indoor servants who unite in their fear and dislike of their master .',
#  "I do n't pretend to understand it all yet , but very curious people anyway .",
#  "There 's no link between the two save for Henderson 's own servant , who serves the family 's meals .",
#  'Henderson never by any chance walks alone .',
#  'Where they came from , or who they are , nobody has an idea .',
#  'Miss Burnet has not been seen by any human eye since the night of the murder .',
#  'There is nothing upon which we can apply for a warrant .',
#  "The woman 's disappearance counts for nothing , since in that extraordinary household any member of it might be invisible for a week .",
#  "We ca n't let such a situation continue .",
#  "If the law can do nothing we must take the risk ourselves . ''",
#  'It was not , I must confess , a very alluring prospect .',
#  'The old house with its atmosphere of murder , the singular and formidable inhabitants , the unknown dangers of the approach , and the fact that we were putting ourselves legally in a false position all combined to damp my ardour .',
#  'But there was something in the ice-cold reasoning of Holmes which made it impossible to shrink from any adventure which he might recommend .',
#  'But it was not destined that our investigation should have so adventurous an ending .',
#  "I sha n't forget the face at the carriage window as I led her away .",
#  '`` I was sure Henderson , as he calls himself , felt that he was suspected , and that he would lie low and make no move so long as he thought he was in any danger .',
#  "We ca n't arrest without her evidence , that is clear , so the sooner we get a statement the better . ''",
#  'Strong , fearless , and energetic , he had sufficient virtue to enable him to impose his odious vices upon a cowering people for ten or twelve years .',
#  '`` I join in it because there is no other way in the world by which justice can be gained .',
#  "To us there is no fiend in hell like Juan Murillo , and no peace in life while his victims still cry for vengeance . ''",
#  'But the many whose lives he had ruined , whose nearest and dearest had suffered torture and death at his hands , would not let the matter rest .',
#  'They banded themselves into a society which should never be dissolved until the work was done .',
#  'He could do little during the day , for Murillo took every precaution and never went out save with his satellite Lucas , or Lopez as he was known in the days of his greatness .',
#  "How they murdered him I do not know , save that it was Murillo 's hand who struck him down , for Lopez had remained to guard me .",
#  '`` All would now have been well for them had it not been for my knowledge of what they had done .',
#  'I have no doubt that there were times when my life hung in the balance .',
#  'I sprang out , they tried to drag me back , and had it not been for the help of this good man , who led me to the cab , I should never had broken away .',
#  "`` Our difficulties are not over , '' he remarked , shaking his head .",
#  "No , no , we shall all be justified when we see the tenants of High Gable at the next Guildford Assizes . ''",
#  'From that day they were seen no more in England .',
#  'The crime was ascribed to Nihilism , and the murderers were never arrested .',
#  'We could not doubt that justice , if belated , had come at last .',
#  '`` It will not be possible for you to present in that compact form which is dear to your heart .',
#  "Is there any point which is not quite clear to you ? ''",
#  '`` ` The true voodoo-worshipper attempts nothing of importance without certain sacrifices which are intended to propitiate his unclean gods .']

# %%
dataset = []
for doc in nlp.pipe(dev_data, n_threads=8, batch_size=10000):
    sent = list(doc.sents)[0]
    key = " ".join([token.text for token in doc])
    dataset.append({
        key :{ 
                        "parse_string":[sent._.parse_string for sent in doc.sents] ,
            "pos_tags":[token.pos_ for token in doc]
    }
                   })
with jsonlines.open('spacy_features_dev.jsonl', 'w') as writer:
    writer.write_all(dataset)

# %%
len(dataset)
# Out:
# 144

# %%
dataset = []
for doc in nlp.pipe(test_data, n_threads=8, batch_size=10000):
    sent = list(doc.sents)[0]
    key = " ".join([token.text for token in doc])
    dataset.append({
        key :{ 
           "parse_string":[sent._.parse_string for sent in doc.sents] ,
            "pos_tags":[token.pos_ for token in doc]
    }
                   })
with jsonlines.open('spacy_features_test.jsonl', 'w') as writer:
    writer.write_all(dataset)

# %%
len(dataset)
# Out:
# 235

# %%
dataset = []
for doc in nlp.pipe(train_data_full, n_threads=8, batch_size=10000):
    sent = list(doc.sents)[0]
    key = " ".join([token.text for token in doc])
    dataset.append({
        key :{ 
           "parse_string":[sent._.parse_string for sent in doc.sents] ,
            "pos_tags":[token.pos_ for token in doc]
    }
                   })
with jsonlines.open('spacy_features_train_full.jsonl', 'w') as writer:
    writer.write_all(dataset)

# %%
len(dataset)
# Out:
# 842

# %%
# !cat spacy_features_train.jsonl spacy_features_dev.jsonl spacy_features_test.jsonl > spacy_features.jsonl

# %%
# !cat spacy_features_train_full.jsonl spacy_features_dev.jsonl spacy_features_test.jsonl > spacy_features_full.jsonl

# %%
# ## convert jsonl to json
# import jsonlines
# output_dict ={}
# with jsonlines.open('spacy_features_test.jsonl') as reader:
#     for obj in reader:
#         for key, value in (obj.items()):
#             output_dict[key]=value
# with jsonlines.open('spacy_features_test.jsonl') as reader:
#     for obj in reader:
#         for key, value in (obj.items()):
#             output_dict[key]=value

# %%
output_dict
# Out:
# {'It is , however , unfortunately impossible entirely to separate the sensational from the criminal , and a chronicler is left in the dilemma that he must either sacrifice details which are essential to his statement and so give a false impression of the problem , or he must use matter which chance , and not choice , has provided him with .': {'parse_string': '(S (S (NP (NP (PRP It))) (VP (VBZ is) (, ,) (ADVP (RB however)) (, ,) (ADVP (RB unfortunately)) (ADJP (JJ impossible)) (ADVP (RB entirely)) (S (VP (TO to) (VP (VB separate) (NP (DT the) (NN sensational)) (PP (IN from) (NP (DT the) (NN criminal)))))))) (, ,) (CC and) (S (NP (DT a) (NN chronicler)) (VP (VBZ is) (VP (VBN left) (PP (IN in) (NP (DT the) (NN dilemma))) (SBAR (IN that) (S (S (NP (PRP he)) (VP (MD must) (CC either) (VP (VP (VB sacrifice) (NP (NP (NNS details)) (SBAR (WHNP (WDT which)) (S (VP (VBP are) (ADJP (JJ essential) (PP (IN to) (NP (PRP$ his) (NN statement))))))))) (CC and) (VP (ADVP (RB so)) (VP (VB give) (NP (NP (DT a) (JJ false) (NN impression)) (PP (IN of) (NP (DT the) (NN problem))))))))) (, ,) (CC or) (S (NP (PRP he)) (VP (MD must) (VP (VB use) (NP (NP (NN matter)) (SBAR (WHNP (WDT which)) (S (NP (NP (NN chance)) (, ,) (CC and) (RB not) (NP (NN choice)) (, ,)) (VP (VBZ has) (VP (VBN provided) (NP (PRP him)) (PP (IN with))))))))))))))) (. .))',
#   'pos_tags': ['PRON',
#    'AUX',
#    'PUNCT',
#    'ADV',
#    'PUNCT',
#    'ADV',
#    'ADJ',
#    'ADV',
#    'PART',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'DET',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'ADP',
#    'DET',
#    'NOUN',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'CCONJ',
#    'VERB',
#    'NOUN',
#    'DET',
#    'AUX',
#    'ADJ',
#    'ADP',
#    'DET',
#    'NOUN',
#    'CCONJ',
#    'ADV',
#    'VERB',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'PRON',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'PART',
#    'NOUN',
#    'PUNCT',
#    'AUX',
#    'VERB',
#    'PRON',
#    'ADP',
#    'PUNCT']},
#  'For myself , my term of service in India had trained me to stand heat better than cold , and a thermometer at ninety was no hardship .': {'parse_string': '(S (PP (IN For) (NP (PRP myself))) (, ,) (S (NP (NP (PRP$ my) (NN term)) (PP (IN of) (NP (NN service))) (PP (IN in) (NP (NNP India)))) (VP (VBD had) (VP (VBN trained) (S (NP (PRP me)) (VP (TO to) (VP (VB stand) (NP (NN heat)) (ADVP (ADVP (RBR better)) (PP (IN than) (ADJP (JJ cold)))))))))) (, ,) (CC and) (S (NP (NP (DT a) (NN thermometer)) (PP (IN at) (NP (CD ninety)))) (VP (VBD was) (NP (DT no) (NN hardship)))) (. .))',
#   'pos_tags': ['ADP',
#    'PRON',
#    'PUNCT',
#    'DET',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'AUX',
#    'VERB',
#    'PRON',
#    'PART',
#    'VERB',
#    'NOUN',
#    'ADV',
#    'SCONJ',
#    'ADJ',
#    'PUNCT',
#    'CCONJ',
#    'DET',
#    'NOUN',
#    'ADP',
#    'NUM',
#    'AUX',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  'But the morning paper was uninteresting .': {'parse_string': '(S (CC But) (NP (DT the) (NN morning) (NN paper)) (VP (VBD was) (ADJP (JJ uninteresting))) (. .))',
#   'pos_tags': ['CCONJ', 'DET', 'NOUN', 'NOUN', 'AUX', 'ADJ', 'PUNCT']},
#  'A depleted bank account had caused me to postpone my holiday , and as to my companion , neither the country nor the sea presented the slightest attraction to him .': {'parse_string': '(S (S (NP (DT A) (JJ depleted) (NN bank) (NN account)) (VP (VBD had) (VP (VBN caused) (S (NP (PRP me)) (VP (TO to) (VP (VB postpone) (NP (PRP$ my) (NN holiday)))))))) (, ,) (CC and) (S (PP (IN as) (PP (IN to) (NP (PRP$ my) (NN companion)))) (, ,) (NP (CC neither) (NP (DT the) (NN country)) (CC nor) (NP (DT the) (NN sea))) (VP (VBD presented) (NP (NP (DT the) (JJS slightest) (NN attraction)) (PP (IN to) (NP (PRP him)))))) (. .))',
#   'pos_tags': ['DET',
#    'ADJ',
#    'NOUN',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'PRON',
#    'PART',
#    'VERB',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'SCONJ',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'DET',
#    'NOUN',
#    'CCONJ',
#    'DET',
#    'NOUN',
#    'VERB',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'PRON',
#    'PUNCT']},
#  'He loved to lie in the very center of five millions of people , with his filaments stretching out and running through them , responsive to every little rumour or suspicion of unsolved crime .': {'parse_string': '(S (NP (PRP He)) (VP (VBD loved) (S (VP (TO to) (VP (VB lie) (IN in) (NP (NP (DT the) (JJ very) (NN center)) (PP (IN of) (NP (NP (NP (CD five) (NNS millions)) (PP (IN of) (NP (NNS people)))) (, ,) (PP (IN with) (S (NP (PRP$ his) (NNS filaments)) (VP (VP (VP (VBG stretching) (ADVP (RP out))) (CC and) (VBG running) (PP (IN through) (NP (PRP them)))) (, ,) (ADJP (JJ responsive) (PP (IN to) (NP (NP (DT every) (JJ little) (NN rumour) (CC or) (NN suspicion)) (PP (IN of) (NP (JJ unsolved) (NN crime)))))))))))))))) (. .))',
#   'pos_tags': ['PRON',
#    'VERB',
#    'PART',
#    'VERB',
#    'ADP',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'NUM',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'PUNCT',
#    'ADP',
#    'DET',
#    'NOUN',
#    'VERB',
#    'ADP',
#    'CCONJ',
#    'VERB',
#    'ADP',
#    'PRON',
#    'PUNCT',
#    'ADJ',
#    'ADP',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'CCONJ',
#    'NOUN',
#    'ADP',
#    'ADJ',
#    'NOUN',
#    'PUNCT']},
#  'Appreciation of nature found no place among his many gifts , and his only change was when he turned his mind from the evil - doer of the town to track down his brother of the country .': {'parse_string': '(S (S (NP (NP (NN Appreciation)) (PP (IN of) (NP (NN nature)))) (VP (VBD found) (NP (DT no) (NN place)) (PP (IN among) (NP (PRP$ his) (JJ many) (NNS gifts))))) (, ,) (CC and) (S (NP (PRP$ his) (JJ only) (NN change)) (VP (VBD was) (SBAR (WHADVP (WRB when)) (S (NP (PRP he)) (VP (VBD turned) (NP (PRP$ his) (NN mind)) (PP (IN from) (NP (NP (DT the) (NNP evil) (HYPH -) (NN doer)) (PP (IN of) (NP (DT the) (NN town))))) (S (VP (TO to) (VP (VB track) (PRT (RP down)) (NP (NP (PRP$ his) (NN brother)) (PP (IN of) (NP (DT the) (NN country)))))))))))) (. .))',
#   'pos_tags': ['NOUN',
#    'ADP',
#    'NOUN',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'ADV',
#    'PRON',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'PROPN',
#    'PUNCT',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PART',
#    'VERB',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  "On my remarking that I was constantly in the habit of doing the same thing you expressed incredulity . ''": {'parse_string': "(S (PP (PP (IN On) (PRP$ my) (NN remarking)) (SBAR (IN that) (S (NP (PRP I)) (VP (VBD was) (ADVP (RB constantly)) (PP (IN in) (NP (NP (DT the) (NN habit)) (PP (IN of) (S (VP (VBG doing) (NP (DT the) (JJ same) (NN thing))))))))))) (NP (PRP you)) (VP (VBD expressed) (NP (NN incredulity))) (. .) ('' ''))",
#   'pos_tags': ['ADP',
#    'DET',
#    'NOUN',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'ADV',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'VERB',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PRON',
#    'VERB',
#    'NOUN',
#    'PUNCT',
#    'PUNCT']},
#  "` ` Oh , no ! ''": {'parse_string': "(FRAG (`` `) (`` `) (INTJ (UH Oh)) (, ,) (INTJ (UH no)) (. !) ('' ''))",
#   'pos_tags': ['PUNCT', 'PUNCT', 'INTJ', 'PUNCT', 'INTJ', 'PUNCT', 'PUNCT']},
#  '` ` Perhaps not with your tongue , my dear Watson , but certainly with your eyebrows .': {'parse_string': '(FRAG (`` `) (`` `) (ADVP (RB Perhaps)) (PP (RB not) (PP (PP (IN with) (NP (PRP$ your) (NN tongue))) (, ,) (NP (PRP$ my) (JJ dear) (NNP Watson))) (, ,) (CC but) (RB certainly) (PP (IN with) (NP (PRP$ your) (NNS eyebrows)))) (. .))',
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'ADV',
#    'PART',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'DET',
#    'ADJ',
#    'PROPN',
#    'PUNCT',
#    'CCONJ',
#    'ADV',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  'But I was still far from satisfied .': {'parse_string': '(S (CC But) (NP (PRP I)) (VP (VBD was) (ADVP (RB still)) (ADVP (RB far) (PP (IN from) (ADJP (JJ satisfied))))) (. .))',
#   'pos_tags': ['CCONJ', 'PRON', 'AUX', 'ADV', 'ADV', 'ADP', 'ADJ', 'PUNCT']},
#  '` ` You do yourself an injustice .': {'parse_string': '(S (`` `) (`` `) (NP (PRP You)) (VP (VBP do) (NP (PRP yourself)) (NP (DT an) (NN injustice))) (. .))',
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'PRON',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  "Perhaps you can not yourself recall how your reverie commenced ? ''": {'parse_string': "(S (ADVP (RB Perhaps)) (NP (PRP you)) (VP (MD can) (RB not) (NP (PRP yourself)) (VP (VB recall) (SBAR (WHADVP (WRB how)) (S (NP (PRP$ your) (NN reverie)) (VP (VBD commenced)))))) (. ?) ('' ''))",
#   'pos_tags': ['ADV',
#    'PRON',
#    'VERB',
#    'PART',
#    'PRON',
#    'VERB',
#    'ADV',
#    'DET',
#    'NOUN',
#    'VERB',
#    'PUNCT',
#    'PUNCT']},
#  "` ` No , I can not . ''": {'parse_string': "(S (`` `) (`` `) (INTJ (UH No)) (, ,) (NP (PRP I)) (VP (MD can) (RB not)) (. .) ('' ''))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'INTJ',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'PART',
#    'PUNCT',
#    'PUNCT']},
#  'But it did not lead very far .': {'parse_string': '(S (CC But) (NP (PRP it)) (VP (VBD did) (RB not) (VP (VB lead) (ADVP (RB very) (RB far)))) (. .))',
#   'pos_tags': ['CCONJ', 'PRON', 'AUX', 'PART', 'VERB', 'ADV', 'ADV', 'PUNCT']},
#  'Your eyes flashed across to the unframed portrait of Henry Ward Beecher which stands upon the top of your books .': {'parse_string': '(S (NP (PRP$ Your) (NNS eyes)) (VP (VBD flashed) (ADVP (RP across)) (PP (IN to) (NP (NP (DT the) (JJ unframed) (NN portrait)) (PP (IN of) (NP (NNP Henry) (NNP Ward) (NNP Beecher))) (SBAR (WHNP (WDT which)) (S (VP (VBZ stands) (PP (IN upon) (NP (NP (DT the) (NN top)) (PP (IN of) (NP (PRP$ your) (NNS books))))))))))) (. .))',
#   'pos_tags': ['DET',
#    'NOUN',
#    'VERB',
#    'ADP',
#    'ADP',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'DET',
#    'VERB',
#    'SCONJ',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  'I was well aware that you could not do this without thinking of the mission which he undertook on behalf of the North at the time of the Civil War , for I remember your expressing your passionate indignation at the way in which he was received by the more turbulent of our people .': {'parse_string': '(S (S (NP (PRP I)) (VP (VBD was) (ADJP (RB well) (JJ aware) (SBAR (IN that) (S (NP (PRP you)) (VP (MD could) (RB not) (VP (VB do) (NP (DT this)) (PP (IN without) (S (VP (NN thinking) (PP (IN of) (NP (NP (DT the) (NN mission)) (SBAR (WHNP (WDT which)) (S (NP (PRP he)) (VP (VBD undertook) (PP (IN on) (NP (NP (NN behalf)) (PP (IN of) (NP (DT the) (NNP North))))) (PP (IN at) (NP (NP (DT the) (NN time)) (PP (IN of) (NP (DT the) (NNP Civil) (NNP War)))))))))))))))))))) (, ,) (SBAR (IN for) (S (NP (PRP I)) (VP (VBP remember) (S (NP (PRP$ your)) (VP (VBG expressing) (NP (NP (PRP$ your) (JJ passionate) (NN indignation)) (PP (IN at) (NP (NP (DT the) (NN way)) (SBAR (WHPP (IN in) (WHNP (WDT which))) (S (NP (PRP he)) (VP (VBD was) (VP (VBN received) (PP (IN by) (NP (NP (DT the) (ADJP (RBR more) (JJ turbulent))) (PP (IN of) (NP (PRP$ our) (NNS people))))))))))))))))) (. .))',
#   'pos_tags': ['PRON',
#    'AUX',
#    'ADV',
#    'ADJ',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'PART',
#    'AUX',
#    'DET',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'DET',
#    'PRON',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'DET',
#    'PROPN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'PROPN',
#    'PROPN',
#    'PUNCT',
#    'ADP',
#    'PRON',
#    'VERB',
#    'DET',
#    'VERB',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'PRON',
#    'AUX',
#    'VERB',
#    'ADP',
#    'DET',
#    'ADV',
#    'ADJ',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  'You felt so strongly about it that I knew you could not think of Beecher without thinking of that also .': {'parse_string': '(S (NP (PRP You)) (VP (VBD felt) (ADVP (ADVP (RB so) (RB strongly))) (PP (IN about) (NP (PRP it))) (SBAR (WDT that) (S (NP (PRP I)) (VP (VBD knew) (SBAR (S (NP (PRP you)) (VP (MD could) (RB not) (VP (VB think) (PP (IN of) (NP (NNP Beecher))) (PP (IN without) (S (VP (VBG thinking) (PP (IN of) (NP (DT that))) (ADVP (RB also))))))))))))) (. .))',
#   'pos_tags': ['PRON',
#    'VERB',
#    'ADV',
#    'ADV',
#    'ADP',
#    'PRON',
#    'DET',
#    'PRON',
#    'VERB',
#    'PRON',
#    'VERB',
#    'PART',
#    'VERB',
#    'ADP',
#    'PROPN',
#    'ADP',
#    'VERB',
#    'ADP',
#    'DET',
#    'ADV',
#    'PUNCT']},
#  'You were dwelling upon the sadness and horror and useless waste of life .': {'parse_string': '(S (NP (PRP You)) (VP (VBD were) (VP (VBG dwelling) (PP (IN upon) (NP (DT the) (NX (NX (NN sadness) (CC and) (NN horror)) (CC and) (NX (NP (JJ useless) (NN waste)) (PP (IN of) (NP (NN life))))))))) (. .))',
#   'pos_tags': ['PRON',
#    'AUX',
#    'VERB',
#    'SCONJ',
#    'DET',
#    'NOUN',
#    'CCONJ',
#    'NOUN',
#    'CCONJ',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'PUNCT']},
#  'I should not have intruded it upon your attention had you not shown some incredulity the other day .': {'parse_string': '(S (NP (PRP I)) (VP (MD should) (RB not) (VP (VB have) (VP (VBN intruded) (NP (PRP it)) (PP (IN upon) (NP (PRP$ your) (NN attention))) (SBAR (SINV (VBD had) (NP (PRP you)) (RB not) (VP (VBN shown) (NP (DT some) (NN incredulity)) (NP (DT the) (JJ other) (NN day)))))))) (. .))',
#   'pos_tags': ['PRON',
#    'VERB',
#    'PART',
#    'AUX',
#    'VERB',
#    'PRON',
#    'SCONJ',
#    'DET',
#    'NOUN',
#    'AUX',
#    'PRON',
#    'PART',
#    'VERB',
#    'DET',
#    'NOUN',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT']},
#  "` ` No , I saw nothing . ''": {'parse_string': "(S (`` `) (`` `) (INTJ (UH No)) (, ,) (NP (PRP I)) (VP (VBD saw) (NP (NN nothing))) (. .) ('' ''))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'INTJ',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'PRON',
#    'PUNCT',
#    'PUNCT']},
#  'There is no indication as to the sender , and the matter is the more mysterious as Miss Cushing , who is a maiden lady of fifty , has led a most retired life , and has so few acquaintances or correspondents that it is a rare event for her to receive anything through the post .': {'parse_string': '(S (S (NP (EX There)) (VP (VBZ is) (NP (NP (DT no) (NN indication)) (PP (IN as) (PP (IN to) (NP (DT the) (NN sender))))))) (, ,) (CC and) (S (NP (DT the) (NN matter)) (VP (VBZ is) (ADJP (DT the) (RBR more) (JJ mysterious)) (SBAR (IN as) (S (NP (NP (NNP Miss) (NNP Cushing)) (, ,) (SBAR (WHNP (WP who)) (S (VP (VBZ is) (NP (NP (DT a) (JJ maiden) (NN lady)) (PP (IN of) (NP (CD fifty))))))) (, ,)) (VP (VP (VBZ has) (VP (VBN led) (NP (DT a) (ADJP (RBS most) (JJ retired)) (NN life)))) (, ,) (CC and) (VP (VBZ has) (NP (NP (ADJP (RB so) (JJ few)) (NNS acquaintances) (CC or) (NNS correspondents)) (SBAR (IN that) (S (NP (NP (PRP it))) (VP (VBZ is) (NP (DT a) (JJ rare) (NN event)) (SBAR (IN for) (S (NP (PRP her)) (VP (TO to) (VP (VB receive) (NP (NN anything)) (PP (IN through) (NP (DT the) (NN post))))))))))))))))) (. .))',
#   'pos_tags': ['PRON',
#    'AUX',
#    'DET',
#    'NOUN',
#    'SCONJ',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'DET',
#    'NOUN',
#    'AUX',
#    'DET',
#    'ADV',
#    'ADJ',
#    'SCONJ',
#    'PROPN',
#    'PROPN',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'NUM',
#    'PUNCT',
#    'AUX',
#    'VERB',
#    'DET',
#    'ADV',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'AUX',
#    'ADV',
#    'ADJ',
#    'NOUN',
#    'CCONJ',
#    'NOUN',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'PRON',
#    'PART',
#    'VERB',
#    'PRON',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  'Some years ago , however , when she resided at Penge , she let apartments in her house to three young medical students , whom she was obliged to get rid of on account of their noisy and irregular habits .': {'parse_string': '(S (ADVP (NP (DT Some) (NNS years)) (RB ago)) (, ,) (ADVP (RB however)) (, ,) (SBAR (WHADVP (WRB when)) (S (NP (PRP she)) (VP (VBD resided) (PP (IN at) (NP (NNP Penge)))))) (, ,) (NP (PRP she)) (VP (VBD let) (NP (NP (NNS apartments)) (PP (IN in) (NP (PRP$ her) (NN house)))) (PP (IN to) (NP (NP (CD three) (JJ young) (JJ medical) (NNS students)) (, ,) (SBAR (WHNP (WP whom)) (S (NP (PRP she)) (VP (VBD was) (VP (VBN obliged) (S (VP (TO to) (VP (VB get) (VBN rid) (PP (IN of)) (PP (IN on) (NP (NP (NN account)) (PP (IN of) (NP (PRP$ their) (ADJP (JJ noisy) (CC and) (JJ irregular)) (NNS habits))))))))))))))) (. .))',
#   'pos_tags': ['DET',
#    'NOUN',
#    'ADV',
#    'PUNCT',
#    'ADV',
#    'PUNCT',
#    'ADV',
#    'PRON',
#    'VERB',
#    'ADP',
#    'PROPN',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'NUM',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'PRON',
#    'PRON',
#    'AUX',
#    'VERB',
#    'PART',
#    'AUX',
#    'VERB',
#    'ADP',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'DET',
#    'ADJ',
#    'CCONJ',
#    'ADJ',
#    'NOUN',
#    'PUNCT']},
#  'We have , of course , wired to the Belfast post - office , but a large number of parcels were handed in upon that day , and they have no means of identifying this particular one , or of remembering the sender .': {'parse_string': '(S (S (NP (PRP We)) (VP (VBP have) (, ,) (PP (IN of) (NP (NN course))) (, ,) (VP (VBN wired) (PP (IN to) (NP (NP (DT the) (NNP Belfast) (NN post)) (JJ -) (NP (JJ office))))))) (, ,) (CC but) (S (S (NP (NP (DT a) (JJ large) (NN number)) (PP (IN of) (NP (NNS parcels)))) (VP (VBD were) (VP (VBN handed) (PRT (RP in)) (PP (IN upon) (NP (DT that) (NN day)))))) (, ,) (CC and) (S (NP (PRP they)) (VP (VBP have) (NP (NP (DT no) (NN means)) (PP (PP (IN of) (S (VP (VBG identifying) (NP (DT this) (JJ particular) (NN one))))) (, ,) (CC or) (PP (IN of) (S (VP (VBG remembering) (NP (DT the) (NN sender)))))))))) (. .))',
#   'pos_tags': ['PRON',
#    'AUX',
#    'PUNCT',
#    'ADP',
#    'NOUN',
#    'PUNCT',
#    'VERB',
#    'ADP',
#    'DET',
#    'PROPN',
#    'NOUN',
#    'ADJ',
#    'ADJ',
#    'PUNCT',
#    'CCONJ',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'ADP',
#    'SCONJ',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'PRON',
#    'AUX',
#    'DET',
#    'NOUN',
#    'ADP',
#    'VERB',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'ADP',
#    'VERB',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  'The box is a half - pound box of honeydew tobacco and does not help us in any way .': {'parse_string': '(S (NP (DT The) (NN box)) (VP (VP (VBZ is) (NP (NP (DT a) (ADJP (JJ half) (HYPH -) (NN pound)) (NN box)) (PP (IN of) (NP (NNP honeydew) (NNP tobacco))))) (CC and) (VP (VBZ does) (RB not) (VP (VB help) (NP (PRP us)) (PP (IN in) (NP (DT any) (NN way)))))) (. .))',
#   'pos_tags': ['DET',
#    'NOUN',
#    'AUX',
#    'DET',
#    'ADJ',
#    'PUNCT',
#    'NOUN',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'CCONJ',
#    'AUX',
#    'PART',
#    'VERB',
#    'PRON',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  "` ` What is the use of asking me questions when I tell you I know nothing whatever about it ? ''": {'parse_string': '(SBARQ (`` `) (`` `) (WHNP (WP What)) (VBZ is) (NP (NP (DT the) (NN use)) (PP (IN of) (S (VP (VBG asking) (NP (PRP me)) (NP (NNS questions)))))) (WHADVP (WRB when)) (S (NP (NP (PRP I)) (VBP tell) (NP (PRP you)) (NP (PRP I))) (VBP know) (NP (NN nothing))))',
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'DET',
#    'NOUN',
#    'ADP',
#    'VERB',
#    'PRON',
#    'NOUN',
#    'ADV',
#    'PRON',
#    'VERB',
#    'PRON',
#    'PRON',
#    'VERB',
#    'PRON',
#    'DET',
#    'ADP',
#    'PRON',
#    'PUNCT',
#    'PUNCT']},
#  "` ` I have no doubt that you have been annoyed more than enough already over this business . ''": {'parse_string': "(S (`` `) (`` `) (NP (PRP I)) (VP (VBP have) (NP (DT no) (NN doubt) (SBAR (IN that) (S (NP (PRP you)) (VP (VBP have) (VP (VBN been) (VP (VBN annoyed) (ADVP (NP (JJR more) (IN than) (ADVP (JJ enough))) (ADVP (RB already))) (PP (IN over) (NP (DT this) (NN business)))))))))) (. .) ('' ''))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'DET',
#    'NOUN',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'AUX',
#    'VERB',
#    'ADJ',
#    'SCONJ',
#    'ADJ',
#    'ADV',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'PUNCT']},
#  "I wo n't have those things in here , Mr. Lestrade .": {'parse_string': "(S (NP (PRP I)) (VP (MD wo) (RB n't) (VP (VB have) (NP (DT those) (NNS things)) (PP (IN in) (NP (RB here))) (, ,) (NP (NNP Mr.) (NNP Lestrade)))) (. .))",
#   'pos_tags': ['PRON',
#    'VERB',
#    'PART',
#    'AUX',
#    'DET',
#    'NOUN',
#    'ADP',
#    'ADV',
#    'PUNCT',
#    'PROPN',
#    'PROPN',
#    'PUNCT']},
#  "` ` I can not see the importance , '' said Lestrade .": {'parse_string': "(SINV (`` `) (`` `) (S (NP (PRP I)) (VP (MD can) (RB not) (VP (VB see) (NP (DT the) (NN importance))))) (, ,) ('' '') (VP (VBD said)) (NP (NNP Lestrade)) (. .))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'PART',
#    'VERB',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'VERB',
#    'PROPN',
#    'PUNCT']},
#  'What , did you not observe it ?': {'parse_string': '(SBARQ (WHNP (WP What)) (, ,) (VBD did) (NP (PRP you)) (RB not) (VP (VB observe) (NP (PRP it))) (. ?))',
#   'pos_tags': ['PRON',
#    'PUNCT',
#    'AUX',
#    'PRON',
#    'PART',
#    'VERB',
#    'PRON',
#    'PUNCT']},
#  'I think there can be no doubt of it .': {'parse_string': '(S (NP (PRP I)) (VP (VBP think) (SBAR (S (NP (EX there)) (VP (MD can) (VP (VB be) (NP (NP (DT no) (NN doubt)) (PP (IN of) (NP (PRP it))))))))) (. .))',
#   'pos_tags': ['PRON',
#    'VERB',
#    'PRON',
#    'VERB',
#    'AUX',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PRON',
#    'PUNCT']},
#  'The parcel was directed , then , by a man -- the printing is distinctly masculine -- of limited education and unacquainted with the town of Croydon .': {'parse_string': '(S (NP (DT The) (NN parcel)) (VP (VBD was) (VP (VBN directed) (, ,) (ADVP (RB then)) (, ,) (PP (IN by) (NP (DT a) (NN man))) (PRN (: --) (S (NP (DT the) (NN printing)) (VP (VBZ is) (ADJP (RB distinctly) (JJ masculine)))) (: --)) (PP (PP (IN of) (NP (JJ limited) (NN education))) (CC and) (ADJP (JJ unacquainted) (PP (IN with) (NP (NP (DT the) (NN town)) (PP (IN of) (NP (NNP Croydon))))))))) (. .))',
#   'pos_tags': ['DET',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'PUNCT',
#    'ADV',
#    'PUNCT',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'DET',
#    'NOUN',
#    'AUX',
#    'ADV',
#    'ADJ',
#    'PUNCT',
#    'ADP',
#    'ADJ',
#    'NOUN',
#    'CCONJ',
#    'ADJ',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PUNCT']},
#  "` ` You have observed , of course , '' said he at last , ` ` that the ears are not a pair . ''": {'parse_string': "(SINV (`` `) (`` `) (NP (PRP You)) (VP (VBP have) (VP (VBN observed) (, ,) (PP (IN of) (NP (NN course))) (, ,) ('' '') (VP (VBD said)) (NP (PRP he)) (PP (IN at) (ADJP (RB last))) (, ,) ('' `) ('' `) (SBAR (IN that) (S (NP (DT the) (NNS ears)) (VP (VBP are) (RB not) (NP (DT a) (NN pair))))))) (. .) ('' ''))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'VERB',
#    'PUNCT',
#    'ADP',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'VERB',
#    'PRON',
#    'ADP',
#    'ADV',
#    'PUNCT',
#    'PUNCT',
#    'PUNCT',
#    'SCONJ',
#    'DET',
#    'NOUN',
#    'AUX',
#    'PART',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'PUNCT']},
#  "But this is not a practical joke . ''": {'parse_string': "(S (CC But) (NP (DT this)) (VP (VBZ is) (RB not) (NP (DT a) (JJ practical) (NN joke))) (. .) ('' ''))",
#   'pos_tags': ['CCONJ',
#    'DET',
#    'AUX',
#    'PART',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'PUNCT']},
#  'These ears bear no signs of this .': {'parse_string': '(S (NP (DT These) (NNS ears)) (VP (VBP bear) (NP (NP (DT no) (NNS signs)) (PP (IN of) (NP (DT this))))) (. .))',
#   'pos_tags': ['DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'PUNCT']},
#  'Again , carbolic or rectified spirits would be the preservatives which would suggest themselves to the medical mind , certainly not rough salt .': {'parse_string': '(S (ADVP (RB Again)) (, ,) (NP (ADJP (JJ carbolic) (CC or) (JJ rectified)) (NNS spirits)) (VP (MD would) (VP (VB be) (NP (NP (DT the) (NNS preservatives)) (SBAR (WHNP (WDT which)) (S (VP (MD would) (VP (VB suggest) (NP (PRP themselves)) (PP (IN to) (NP (DT the) (JJ medical) (NN mind))) (, ,) (ADVP (RB certainly)) (RB not) (NP (JJ rough) (NN salt))))))))) (. .))',
#   'pos_tags': ['ADV',
#    'PUNCT',
#    'ADJ',
#    'CCONJ',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'AUX',
#    'DET',
#    'NOUN',
#    'DET',
#    'VERB',
#    'VERB',
#    'PRON',
#    'ADP',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'ADV',
#    'PART',
#    'ADJ',
#    'NOUN',
#    'PUNCT']},
#  "I repeat that there is no practical joke here , but that we are investigating a serious crime . ''": {'parse_string': "(S (NP (PRP I)) (VP (VBP repeat) (SBAR (SBAR (IN that) (S (NP (EX there)) (VP (VBZ is) (NP (DT no) (JJ practical) (NN joke)) (ADVP (RB here))))) (, ,) (CC but) (SBAR (IN that) (S (NP (PRP we)) (VP (VBP are) (VP (VBG investigating) (NP (DT a) (JJ serious) (NN crime)))))))) (. .) ('' ''))",
#   'pos_tags': ['PRON',
#    'VERB',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADV',
#    'PUNCT',
#    'CCONJ',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'VERB',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'PUNCT']},
#  'This brutal preliminary seemed to shadow forth some strange and inexplicable horror in the background .': {'parse_string': '(S (NP (DT This) (JJ brutal) (NN preliminary)) (VP (VBD seemed) (S (VP (TO to) (VP (VB shadow) (PRT (RB forth)) (NP (DT some) (ADJP (JJ strange) (CC and) (JJ inexplicable)) (NN horror)) (PP (IN in) (NP (DT the) (NN background))))))) (. .))',
#   'pos_tags': ['DET',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'PART',
#    'VERB',
#    'ADV',
#    'DET',
#    'ADJ',
#    'CCONJ',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  "The other is a man 's , sun - burned , discoloured , and also pierced for an earring .": {'parse_string': "(S (NP (DT The) (JJ other)) (VP (VBZ is) (NP (NP (NP (DT a) (NN man) (POS 's)) (, ,) (NN sun)) (HYPH -) (UCP (VBN burned) (, ,) (VBN discoloured) (, ,) (CC and) (VP (ADVP (RB also)) (VBN pierced) (PP (IN for) (NP (DT an) (NN earring))))))) (. .))",
#   'pos_tags': ['DET',
#    'ADJ',
#    'AUX',
#    'DET',
#    'NOUN',
#    'PART',
#    'PUNCT',
#    'NOUN',
#    'PUNCT',
#    'VERB',
#    'PUNCT',
#    'VERB',
#    'PUNCT',
#    'CCONJ',
#    'ADV',
#    'VERB',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  'She might have buried the ears , and no one would have been the wiser .': {'parse_string': '(S (S (NP (PRP She)) (VP (MD might) (VP (VB have) (VP (VBN buried) (NP (DT the) (NNS ears)))))) (, ,) (CC and) (S (NP (DT no) (PRP one)) (VP (MD would) (VP (VB have) (VP (VBN been) (NP (DT the) (JJR wiser)))))) (. .))',
#   'pos_tags': ['PRON',
#    'VERB',
#    'AUX',
#    'VERB',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'DET',
#    'PRON',
#    'VERB',
#    'AUX',
#    'AUX',
#    'DET',
#    'ADJ',
#    'PUNCT']},
#  'But if she does not wish to shield him she would give his name .': {'parse_string': '(S (CC But) (SBAR (IN if) (S (NP (PRP she)) (VP (VBZ does) (RB not) (VP (VB wish) (S (VP (TO to) (VP (VB shield) (NP (PRP him))))))))) (NP (PRP she)) (VP (MD would) (VP (VB give) (NP (PRP$ his) (NN name)))) (. .))',
#   'pos_tags': ['CCONJ',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'PART',
#    'VERB',
#    'PRON',
#    'PRON',
#    'VERB',
#    'VERB',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  'I think that I have nothing further to learn from Miss Cushing .': {'parse_string': '(S (NP (PRP I)) (VP (VBP think) (SBAR (IN that) (S (NP (PRP I)) (VP (VBP have) (NP (NP (NN nothing) (RB further)) (SBAR (S (VP (TO to) (VP (VB learn) (PP (IN from) (NP (NNP Miss) (NNP Cushing)))))))))))) (. .))',
#   'pos_tags': ['PRON',
#    'VERB',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'PRON',
#    'ADV',
#    'PART',
#    'VERB',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'PUNCT']},
#  "` ` I am convinced , sir , '' she said , ` ` that this matter is a mistake , and that the parcel was never meant for me at all .": {'parse_string': "(S (`` `) (`` `) (NP (PRP I)) (VBP am) (ADJP (JJ convinced) (, ,) (INTJ (NNP sir)) (, ,) ('' '') (NP (PRP she)) (VP (VBD said) (, ,) (`` `) ('' `) (SBAR (SBAR (IN that) (S (NP (DT this) (NN matter)) (VP (VBZ is) (NP (DT a) (NN mistake))))) (, ,) (CC and) (SBAR (IN that) (S (NP (DT the) (NN parcel)) (VP (VBD was) (ADVP (RB never)) (VP (VBN meant) (PP (IN for) (NP (PRP me))) (ADVP (RB at) (RB all))))))))) (. .))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'ADJ',
#    'PUNCT',
#    'PROPN',
#    'PUNCT',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'PUNCT',
#    'PUNCT',
#    'PUNCT',
#    'SCONJ',
#    'DET',
#    'NOUN',
#    'AUX',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'SCONJ',
#    'DET',
#    'NOUN',
#    'AUX',
#    'ADV',
#    'VERB',
#    'ADP',
#    'PRON',
#    'ADV',
#    'ADV',
#    'PUNCT']},
#  "I have not an enemy in the world , as far as I know , so why should anyone play me such a trick ? ''": {'parse_string': "(S (S (NP (PRP I)) (VP (VBP have) (RB not) (NP (DT an) (NN enemy)) (PP (IN in) (NP (DT the) (NN world))) (, ,) (ADVP (ADVP (RB as) (RB far)) (SBAR (IN as) (S (NP (PRP I)) (VP (VBP know))))))) (, ,) (RB so) (WHADVP (WRB why)) (SQ (MD should) (NP (NN anyone)) (VP (VB play) (NP (PRP me)) (NP (PDT such) (DT a) (NN trick)))) (. ?) ('' ''))",
#   'pos_tags': ['PRON',
#    'AUX',
#    'PART',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'ADV',
#    'ADV',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'PUNCT',
#    'ADV',
#    'ADV',
#    'VERB',
#    'PRON',
#    'VERB',
#    'PRON',
#    'DET',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'PUNCT']},
#  "I stared hard myself at her flat , grizzled hair , her trim cap , her little gilt earrings , her placid features ; but I could see nothing which could account for my companion 's evident excitement .": {'parse_string': "(S (S (NP (PRP I)) (VP (VBD stared) (ADVP (RB hard)) (NP (PRP myself)) (PP (IN at) (NP (NP (PRP$ her) (JJ flat) (, ,) (JJ grizzled) (NN hair)) (, ,) (NP (PRP$ her) (NN trim) (NN cap)) (, ,) (NP (PRP$ her) (JJ little) (JJ gilt) (NNS earrings)) (, ,) (NP (PRP$ her) (JJ placid) (NNS features)))))) (: ;) (CC but) (S (NP (PRP I)) (VP (MD could) (VP (VB see) (NP (NP (NN nothing)) (SBAR (WHNP (WDT which)) (S (VP (MD could) (VP (VB account) (PP (IN for) (NP (NP (PRP$ my) (NN companion) (POS 's)) (JJ evident) (NN excitement))))))))))) (. .))",
#   'pos_tags': ['PRON',
#    'VERB',
#    'ADV',
#    'PRON',
#    'ADP',
#    'DET',
#    'ADJ',
#    'PUNCT',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'DET',
#    'NOUN',
#    'NOUN',
#    'PUNCT',
#    'DET',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'PRON',
#    'VERB',
#    'VERB',
#    'PRON',
#    'DET',
#    'VERB',
#    'VERB',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PART',
#    'ADJ',
#    'NOUN',
#    'PUNCT']},
#  "` ` Oh , I am weary of questions ! '' cried Miss Cushing impatiently .": {'parse_string': "(S (`` `) (`` `) (INTJ (UH Oh)) (, ,) (NP (PRP I)) (VP (VBP am) (ADJP (JJ weary) (PP (IN of) (NP (NNS questions))))) (. !) ('' ''))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'INTJ',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'ADJ',
#    'ADP',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'ADV',
#    'PUNCT']},
#  "` ` I observed the very instant that I entered the room that you have a portrait group of three ladies upon the mantelpiece , one of whom is undoubtedly yourself , while the others are so exceedingly like you that there could be no doubt of the relationship . ''": {'parse_string': "(S (`` `) (`` `) (NP (PRP I)) (VP (VBD observed) (NP (NP (DT the) (RB very) (NN instant)) (SBAR (IN that) (S (NP (PRP I)) (VP (VBD entered) (NP (DT the) (NN room)))))) (SBAR (WDT that) (S (NP (PRP you)) (VP (VBP have) (NP (NP (DT a) (NN portrait) (NN group)) (PP (IN of) (NP (CD three) (NNS ladies)))) (PP (IN upon) (NP (DT the) (NN mantelpiece))) (, ,) (SBAR (WHNP (CD one) (WHPP (IN of) (WHNP (WP whom)))) (S (VP (VBZ is) (ADVP (RB undoubtedly)) (NP (PRP yourself))))) (, ,) (SBAR (IN while) (S (NP (DT the) (NNS others)) (VP (VBP are) (PP (PP (ADVP (RB so) (RB exceedingly)) (IN like) (NP (PRP you))) (SBAR (IN that) (S (NP (EX there)) (VP (MD could) (VP (VB be) (NP (NP (DT no) (NN doubt)) (PP (IN of) (NP (DT the) (NN relationship)))))))))))))))) (. .) ('' ''))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'DET',
#    'ADV',
#    'NOUN',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'DET',
#    'NOUN',
#    'DET',
#    'PRON',
#    'AUX',
#    'DET',
#    'NOUN',
#    'NOUN',
#    'ADP',
#    'NUM',
#    'NOUN',
#    'SCONJ',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'NUM',
#    'ADP',
#    'PRON',
#    'AUX',
#    'ADV',
#    'PRON',
#    'PUNCT',
#    'SCONJ',
#    'DET',
#    'NOUN',
#    'AUX',
#    'ADV',
#    'ADV',
#    'SCONJ',
#    'PRON',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'AUX',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'PUNCT']},
#  "I observe that she was unmarried at the time . ''": {'parse_string': "(S (NP (PRP I)) (VP (VBP observe) (SBAR (IN that) (S (NP (PRP she)) (VP (VBD was) (ADJP (JJ unmarried)) (PP (IN at) (NP (DT the) (NN time))))))) (. .) ('' ''))",
#   'pos_tags': ['PRON',
#    'VERB',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'ADJ',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'PUNCT']},
#  "He was on the South American line when that was taken , but he was so fond of her that he could n't abide to leave her for so long , and he got into the Liverpool and London boats . ''": {'parse_string': "(S (S (NP (PRP He)) (VP (VBD was) (PP (IN on) (NP (DT the) (ADJP (JJ South) (JJ American)) (NN line))) (SBAR (WHADVP (WRB when)) (S (NP (DT that)) (VP (VBD was) (VP (VBN taken))))))) (, ,) (CC but) (S (NP (PRP he)) (VP (VBD was) (ADJP (ADJP (RB so) (JJ fond) (PP (IN of) (NP (PRP her)))) (SBAR (IN that) (S (S (NP (PRP he)) (VP (MD could) (RB n't) (VP (VB abide) (S (VP (TO to) (VP (VB leave) (NP (PRP her)) (PP (IN for) (ADVP (RB so) (RB long))))))))) (, ,) (CC and) (S (NP (PRP he)) (VP (VBD got) (PP (IN into) (NP (DT the) (NNP Liverpool) (CC and) (NNP London) (NNS boats)))))))))) (. .) ('' ''))",
#   'pos_tags': ['PRON',
#    'AUX',
#    'ADP',
#    'DET',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'ADV',
#    'DET',
#    'AUX',
#    'VERB',
#    'PUNCT',
#    'CCONJ',
#    'PRON',
#    'AUX',
#    'ADV',
#    'ADJ',
#    'ADP',
#    'PRON',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'PART',
#    'VERB',
#    'PART',
#    'VERB',
#    'PRON',
#    'ADP',
#    'ADV',
#    'ADV',
#    'PUNCT',
#    'CCONJ',
#    'PRON',
#    'VERB',
#    'ADP',
#    'DET',
#    'PROPN',
#    'CCONJ',
#    'PROPN',
#    'NOUN',
#    'PUNCT',
#    'PUNCT']},
#  '` ` No , the May Day , when last I heard .': {'parse_string': '(FRAG (`` `) (`` `) (NP (UH No)) (, ,) (NP (DT the) (NNP May) (NNP Day)) (, ,) (SBAR (WHADVP (WRB when)) (S (NP (JJ last) (PRP I)) (VP (VBD heard)))) (. .))',
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'INTJ',
#    'PUNCT',
#    'DET',
#    'PROPN',
#    'PROPN',
#    'PUNCT',
#    'ADV',
#    'ADJ',
#    'PRON',
#    'VERB',
#    'PUNCT']},
#  "First he dropped me , then he quarrelled with Sarah , and now that Mary has stopped writing we do n't know how things are going with them . ''": {'parse_string': "(S (S (S (ADVP (RB First)) (NP (PRP he)) (VP (VBD dropped) (NP (PRP me)))) (, ,) (S (ADVP (RB then)) (NP (PRP he)) (VP (VBD quarrelled) (PP (IN with) (NP (NNP Sarah)))))) (, ,) (CC and) (S (SBAR (RB now) (IN that) (S (NP (NNP Mary)) (VP (VBZ has) (VP (VBN stopped) (S (VP (VBG writing))))))) (NP (PRP we)) (VP (VBP do) (RB n't) (VP (VB know) (SBAR (WHADVP (WRB how)) (S (NP (NNS things)) (VP (VBP are) (VP (VBG going) (PP (IN with) (NP (PRP them)))))))))) (. .) ('' ''))",
#   'pos_tags': ['ADV',
#    'PRON',
#    'VERB',
#    'PRON',
#    'PUNCT',
#    'ADV',
#    'PRON',
#    'VERB',
#    'ADP',
#    'PROPN',
#    'PUNCT',
#    'CCONJ',
#    'ADV',
#    'SCONJ',
#    'PROPN',
#    'AUX',
#    'VERB',
#    'VERB',
#    'PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'ADV',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'ADP',
#    'PRON',
#    'PUNCT',
#    'PUNCT']},
#  "` ` I wonder , since you are both maiden ladies , that you do not keep house together . ''": {'parse_string': "(S (`` `) (`` `) (NP (PRP I)) (VP (VBP wonder) (, ,) (SBAR (SBAR (IN since) (S (NP (PRP you)) (VP (VBP are) (DT both) (NP (JJ maiden) (NNS ladies))))) (, ,) (SBAR (IN that) (S (NP (PRP you)) (VP (VBP do) (RB not) (VP (VB keep) (NP (NN house)) (ADVP (RB together)))))))) (. .) ('' ''))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'PUNCT',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'NOUN',
#    'ADV',
#    'PUNCT',
#    'PUNCT']},
#  "` ` Ah ! you do n't know Sarah 's temper or you would wonder no more .": {'parse_string': '(NP (`` `) (`` `) (UH Ah) (. !))',
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'INTJ',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'PROPN',
#    'PART',
#    'NOUN',
#    'CCONJ',
#    'PRON',
#    'VERB',
#    'VERB',
#    'ADV',
#    'ADV',
#    'PUNCT']},
#  "I do n't want to say a word against my own sister , but she was always meddlesome and hard to please , was Sarah . ''": {'parse_string': "(S (S (NP (PRP I)) (VP (VBP do) (RB n't) (VP (VB want) (S (VP (TO to) (VP (VB say) (NP (DT a) (NN word)) (PP (IN against) (NP (PRP$ my) (JJ own) (NN sister))))))))) (, ,) (CC but) (S (NP (PRP she)) (VP (VP (VBD was) (ADVP (RB always)) (ADJP (ADJP (JJ meddlesome)) (CC and) (ADJP (JJ hard) (SBAR (S (VP (TO to) (VP (VB please)))))))) (, ,) (VP (VP (VBD was)) (NP (NNP Sarah))))) (. .) ('' ''))",
#   'pos_tags': ['PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'PART',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'PRON',
#    'AUX',
#    'ADV',
#    'ADJ',
#    'CCONJ',
#    'ADJ',
#    'PART',
#    'VERB',
#    'PUNCT',
#    'AUX',
#    'PROPN',
#    'PUNCT',
#    'PUNCT']},
#  'And now she has no word hard enough for Jim Browner .': {'parse_string': '(S (CC And) (ADVP (RB now)) (NP (PRP she)) (VP (VBZ has) (NP (NP (DT no) (NN word)) (ADJP (JJ hard) (RB enough) (PP (IN for) (NP (NNP Jim) (NNP Browner)))))) (. .))',
#   'pos_tags': ['CCONJ',
#    'ADV',
#    'PRON',
#    'AUX',
#    'DET',
#    'NOUN',
#    'ADJ',
#    'ADV',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'PUNCT']},
#  "Good - bye , and I am very sorry that you should have been troubled over a case with which , as you say , you have nothing whatever to do . ''": {'parse_string': '(FRAG (ADJP (JJ Good)) (HYPH -) (INTJ (NN bye)) (, ,) (CC and))',
#   'pos_tags': ['ADJ',
#    'PUNCT',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'PRON',
#    'AUX',
#    'ADV',
#    'ADJ',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'AUX',
#    'AUX',
#    'VERB',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'PUNCT',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'PRON',
#    'DET',
#    'PART',
#    'AUX',
#    'PUNCT',
#    'PUNCT']},
#  'Our drive pulled up at a house which was not unlike the one which we had just quitted .': {'parse_string': '(S (NP (PRP$ Our) (NN drive)) (VP (VBD pulled) (PRT (RP up)) (PP (IN at) (NP (NP (DT a) (NN house)) (SBAR (WHNP (WDT which)) (S (VP (VBD was) (RB not) (PP (IN unlike) (NP (NP (DT the) (NN one)) (SBAR (WHNP (WDT which)) (S (NP (PRP we)) (VP (VBD had) (ADVP (RB just)) (VP (VBN quitted))))))))))))) (. .))',
#   'pos_tags': ['DET',
#    'NOUN',
#    'VERB',
#    'ADP',
#    'ADP',
#    'DET',
#    'NOUN',
#    'DET',
#    'AUX',
#    'PART',
#    'ADP',
#    'DET',
#    'NOUN',
#    'DET',
#    'PRON',
#    'AUX',
#    'ADV',
#    'VERB',
#    'PUNCT']},
#  'As her medical adviser , I can not possibly take the responsibility of allowing anyone to see her .': {'parse_string': '(S (PP (IN As) (NP (PRP$ her) (JJ medical) (NN adviser))) (, ,) (NP (PRP I)) (VP (MD can) (RB not) (ADVP (RB possibly)) (VP (VB take) (NP (NP (DT the) (NN responsibility)) (PP (IN of) (S (VP (VBG allowing) (S (NP (NN anyone)) (VP (TO to) (VP (VB see) (NP (PRP her))))))))))) (. .))',
#   'pos_tags': ['SCONJ',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'PART',
#    'ADV',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'VERB',
#    'PRON',
#    'PART',
#    'VERB',
#    'PRON',
#    'PUNCT']},
#  "` ` Well , if we ca n't we ca n't , '' said Holmes , cheerfully .": {'parse_string': "(SINV (`` `) (`` `) (S (INTJ (UH Well)) (, ,) (SBAR (IN if) (S (NP (PRP we)) (VP (MD ca) (RB n't) (NP (PRP we)) (VP (MD ca) (RB n't)))))) (, ,) ('' '') (VP (VBD said)) (NP (NNP Holmes)) (, ,) (ADVP (RB cheerfully)) (. .))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'INTJ',
#    'PUNCT',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'PART',
#    'PRON',
#    'VERB',
#    'PART',
#    'PUNCT',
#    'PUNCT',
#    'VERB',
#    'PROPN',
#    'PUNCT',
#    'ADV',
#    'PUNCT']},
#  "` ` Perhaps she could not or would not have told you much . ''": {'parse_string': "(S (`` `) (`` `) (ADVP (RB Perhaps)) (NP (PRP she)) (VP (VP (MD could) (RB not)) (CC or) (MD would) (RB not) (VB have) (VBN told) (NP (PRP you)) (NP (JJ much))) (. .) ('' ''))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'ADV',
#    'PRON',
#    'VERB',
#    'PART',
#    'CCONJ',
#    'VERB',
#    'PART',
#    'AUX',
#    'VERB',
#    'PRON',
#    'ADJ',
#    'PUNCT',
#    'PUNCT']},
#  '` ` I did not wish her to tell me anything .': {'parse_string': '(S (`` `) (`` `) (NP (PRP I)) (VP (VBD did) (RB not) (VP (VB wish) (S (NP (PRP her)) (VP (TO to) (VP (VB tell) (NP (PRP me)) (NP (NN anything))))))) (. .))',
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'PRON',
#    'PART',
#    'VERB',
#    'PRON',
#    'PRON',
#    'PUNCT']},
#  '` ` I was never more serious in my life .': {'parse_string': '(S (`` `) (`` `) (NP (PRP I)) (VP (VBD was) (ADVP (RB never)) (ADJP (RBR more) (JJ serious)) (PP (IN in) (NP (PRP$ my) (NN life)))) (. .))',
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'ADV',
#    'ADV',
#    'ADJ',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  '` ` You can not effect an arrest until to - morrow night at the earliest .': {'parse_string': '(S (`` `) (`` `) (NP (PRP You)) (VP (MD can) (RB not) (VP (VB effect) (NP (DT an) (NN arrest)) (PP (IN until) (NP (NP (TO to)) (HYPH -) (NP (NP (NN morrow) (NN night)) (PP (IN at) (NP (DT the) (JJS earliest)))))))) (. .))',
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'PART',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PART',
#    'PUNCT',
#    'NOUN',
#    'NOUN',
#    'ADP',
#    'DET',
#    'ADJ',
#    'PUNCT']},
#  'I should prefer that you do not mention my name at all in connection with the case , as I choose to be only associated with those crimes which present some difficulty in their solution .': {'parse_string': '(S (NP (PRP I)) (VP (MD should) (VP (VB prefer) (SBAR (IN that) (S (NP (PRP you)) (VP (VBP do) (RB not) (VP (VB mention) (NP (PRP$ my) (NN name)) (ADVP (RB at) (RB all)) (PP (IN in) (NP (NP (NN connection)) (PP (IN with) (NP (DT the) (NN case))))) (, ,) (SBAR (IN as) (S (NP (PRP I)) (VP (VBP choose) (S (VP (TO to) (VP (VB be) (ADVP (RB only)) (VP (VBN associated) (PP (IN with) (NP (NP (DT those) (NNS crimes)) (SBAR (WHNP (WDT which)) (S (VP (VBP present) (NP (DT some) (NN difficulty)) (PP (IN in) (NP (PRP$ their) (NN solution))))))))))))))))))))) (. .))',
#   'pos_tags': ['PRON',
#    'VERB',
#    'VERB',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADV',
#    'ADV',
#    'ADP',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'PART',
#    'AUX',
#    'ADV',
#    'VERB',
#    'ADP',
#    'DET',
#    'NOUN',
#    'DET',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  "` ` Your case is not complete , then ? '' I asked .": {'parse_string': "(S (`` `) (`` `) (NP (PRP$ Your) (NN case)) (VP (VBZ is) (RB not) (ADJP (JJ complete)) (, ,) (ADVP (RB then))) (. ?) ('' ''))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'DET',
#    'NOUN',
#    'AUX',
#    'PART',
#    'ADJ',
#    'PUNCT',
#    'ADV',
#    'PUNCT',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'PUNCT']},
#  "` ` And yet I can not see anything save very vague indications . ''": {'parse_string': "(S (`` `) (`` `) (CC And) (ADVP (RB yet)) (NP (PRP I)) (VP (MD can) (RB not) (VP (VB see) (NP (NP (NN anything)) (VP (VB save) (NP (ADJP (RB very) (JJ vague)) (NNS indications)))))) (. .) ('' ''))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'CCONJ',
#    'ADV',
#    'PRON',
#    'VERB',
#    'PART',
#    'VERB',
#    'PRON',
#    'VERB',
#    'ADV',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'PUNCT']},
#  '` ` On the contrary , to my mind nothing could be more clear .': {'parse_string': '(S (`` `) (`` `) (PP (IN On) (NP (DT the) (NN contrary))) (, ,) (PP (IN to) (NP (PRP$ my) (NN mind))) (NP (NN nothing)) (VP (MD could) (VP (VB be) (ADJP (RBR more) (JJ clear)))) (. .))',
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PRON',
#    'VERB',
#    'AUX',
#    'ADV',
#    'ADJ',
#    'PUNCT']},
#  'We had formed no theories .': {'parse_string': '(S (NP (PRP We)) (VP (VBD had) (VP (VBN formed) (NP (DT no) (NNS theories)))) (. .))',
#   'pos_tags': ['PRON', 'AUX', 'VERB', 'DET', 'NOUN', 'PUNCT']},
#  '` ` As a medical man , you are aware , Watson , that there is no part of the body which varies so much as the human ear .': {'parse_string': '(S (`` `) (`` `) (PP (IN As) (NP (DT a) (JJ medical) (NN man))) (, ,) (NP (PRP you)) (VP (VBP are) (ADJP (JJ aware) (, ,) (NP (NNP Watson)) (, ,) (SBAR (IN that) (S (NP (EX there)) (VP (VBZ is) (NP (NP (DT no) (NN part)) (PP (IN of) (NP (DT the) (NN body))) (SBAR (WHNP (WDT which)) (S (VP (VBZ varies) (ADVP (ADVP (RB so) (RB much)) (PP (IN as) (NP (DT the) (JJ human) (NN ear))))))))))))) (. .))',
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'SCONJ',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'ADJ',
#    'PUNCT',
#    'PROPN',
#    'PUNCT',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'DET',
#    'VERB',
#    'ADV',
#    'ADV',
#    'SCONJ',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT']},
#  'This quarrel had put a stop to all communications for some months , so that if Browner had occasion to address a packet to Miss Sarah , he would undoubtedly have done so to her old address .': {'parse_string': '(S (NP (DT This) (NN quarrel)) (VP (VBD had) (VP (VBN put) (NP (DT a) (NN stop)) (PP (IN to) (NP (DT all) (NNS communications))) (PP (IN for) (NP (DT some) (NNS months))) (, ,) (SBAR (IN so) (IN that) (S (SBAR (IN if) (S (NP (NNP Browner)) (VP (VBD had) (NP (NP (NN occasion)) (SBAR (S (VP (TO to) (VP (VB address) (NP (DT a) (NN packet)) (PP (IN to) (NP (NNP Miss) (NNP Sarah))))))))))) (, ,) (NP (PRP he)) (VP (MD would) (ADVP (RB undoubtedly)) (VP (VB have) (VP (VBN done) (ADVP (RB so)) (PP (IN to) (NP (PRP$ her) (JJ old) (NN address)))))))))) (. .))',
#   'pos_tags': ['DET',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'SCONJ',
#    'SCONJ',
#    'SCONJ',
#    'PROPN',
#    'AUX',
#    'NOUN',
#    'PART',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'ADV',
#    'AUX',
#    'VERB',
#    'ADV',
#    'ADP',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT']},
#  '` ` A second solution was at this stage obviously possible , and although I thought it exceedingly unlikely , I was determined to elucidate it before going further .': {'parse_string': '(S (`` `) (`` `) (S (NP (DT A) (JJ second) (NN solution)) (VP (VBD was) (PP (IN at) (NP (DT this) (NN stage))) (ADJP (RB obviously) (JJ possible)))) (, ,) (CC and) (S (SBAR (IN although) (S (NP (PRP I)) (VP (VBD thought) (S (NP (PRP it)) (ADJP (RB exceedingly) (JJ unlikely)))))) (, ,) (NP (PRP I)) (VP (VBD was) (VP (JJ determined) (S (VP (TO to) (VP (VB elucidate) (NP (PRP it)) (PP (IN before) (S (VP (VBG going) (ADVP (RBR further))))))))))) (. .))',
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADV',
#    'ADJ',
#    'PUNCT',
#    'CCONJ',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'PRON',
#    'ADV',
#    'ADJ',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'ADJ',
#    'PART',
#    'VERB',
#    'PRON',
#    'ADP',
#    'VERB',
#    'ADV',
#    'PUNCT']},
# ...
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'INTJ',
#    'PUNCT',
#    'PROPN',
#    'PROPN',
#    'PUNCT',
#    'PUNCT',
#    'VERB',
#    'DET',
#    'ADJ',
#    'PROPN',
#    'PUNCT',
#    'VERB',
#    'DET',
#    'NOUN',
#    'SCONJ',
#    'DET',
#    'NOUN',
#    'PART',
#    'NOUN',
#    'ADP',
#    'ADV',
#    'ADJ',
#    'NOUN',
#    'SCONJ',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'DET',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'PART',
#    'ADV',
#    'ADJ',
#    'ADV',
#    'PRON',
#    'PRON',
#    'AUX',
#    'CCONJ',
#    'PRON',
#    'PRON',
#    'AUX',
#    'PUNCT',
#    'CCONJ',
#    'PRON',
#    'PUNCT',
#    'PROPN',
#    'VERB',
#    'ADJ',
#    'PART',
#    'VERB',
#    'PRON',
#    'ADV',
#    'ADJ',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'VERB',
#    'PRON',
#    'ADP',
#    'DET',
#    'PROPN',
#    'PUNCT',
#    'PUNCT']},
#  "But if you think that he has acted from motives which are not criminal , and which he would wish to have known , then you can not serve him better than by telling us the whole story . ''": {'parse_string': "(S (CC But) (SBAR (IN if) (S (NP (PRP you)) (VP (VBP think) (SBAR (SBAR (IN that) (S (NP (PRP he)) (VP (VBZ has) (VP (VBN acted) (PP (IN from) (NP (NP (NNS motives)) (SBAR (WHNP (WDT which)) (S (VP (VBP are) (RB not) (ADJP (JJ criminal))))))))))) (, ,) (CC and) (SBAR (WHNP (WDT which)) (S (NP (PRP he)) (VP (MD would) (VP (VB wish) (S (VP (TO to) (VP (VB have) (VP (VBN known))))))))))))) (, ,) (ADVP (RB then)) (NP (PRP you)) (VP (MD can) (RB not) (VP (VB serve) (NP (PRP him)) (ADVP (ADVP (RBR better)) (PP (IN than) (PP (IN by) (S (VP (VBG telling) (NP (PRP us)) (NP (DT the) (JJ whole) (NN story))))))))) (. .) ('' ''))",
#   'pos_tags': ['CCONJ',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'DET',
#    'AUX',
#    'PART',
#    'ADJ',
#    'PUNCT',
#    'CCONJ',
#    'DET',
#    'PRON',
#    'VERB',
#    'VERB',
#    'PART',
#    'AUX',
#    'VERB',
#    'PUNCT',
#    'ADV',
#    'PRON',
#    'VERB',
#    'PART',
#    'VERB',
#    'PRON',
#    'ADV',
#    'SCONJ',
#    'ADP',
#    'VERB',
#    'PRON',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'PUNCT']},
#  "` ` Now that Gorgiano is dead we fear nothing , '' said the lady .": {'parse_string': "(SINV (`` `) (`` `) (S (ADVP (RB Now) (SBAR (IN that) (S (NP (NNP Gorgiano)) (VP (VBZ is) (ADJP (JJ dead)))))) (NP (PRP we)) (VP (VBP fear) (NP (NN nothing)))) (, ,) ('' '') (VP (VBD said)) (NP (DT the) (NN lady)) (. .))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'ADV',
#    'SCONJ',
#    'PROPN',
#    'AUX',
#    'ADJ',
#    'PRON',
#    'VERB',
#    'PRON',
#    'PUNCT',
#    'PUNCT',
#    'VERB',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  "` ` He was a devil and a monster , and there can be no judge in the world who would punish my husband for having killed him . ''": {'parse_string': "(S (`` `) (`` `) (S (NP (PRP He)) (VP (VBD was) (NP (NP (DT a) (NN devil)) (CC and) (NP (DT a) (NN monster))))) (, ,) (CC and) (S (NP (EX there)) (VP (MD can) (VP (VB be) (NP (NP (DT no) (NN judge)) (PP (IN in) (NP (DT the) (NN world))) (SBAR (WHNP (WP who)) (S (VP (MD would) (VP (VB punish) (NP (PRP$ my) (NN husband)) (PP (IN for) (S (VP (VBG having) (VP (VBN killed) (NP (PRP him)))))))))))))) (. .) ('' ''))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'DET',
#    'NOUN',
#    'CCONJ',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'PRON',
#    'VERB',
#    'AUX',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PRON',
#    'VERB',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'VERB',
#    'VERB',
#    'PRON',
#    'PUNCT',
#    'PUNCT']},
#  'She spoke in rapid and fluent but very unconventional English , which , for the sake of clearness , I will make grammatical .': {'parse_string': '(S (NP (PRP She)) (VP (VBD spoke) (PP (IN in) (NP (NP (ADJP (ADJP (ADJP (JJ rapid)) (CC and) (ADJP (JJ fluent))) (CC but) (ADJP (RB very) (JJ unconventional))) (NNP English)) (, ,) (SBAR (WHNP (WDT which)) (, ,) (S (PP (IN for) (NP (NP (DT the) (NN sake)) (PP (IN of) (NP (NN clearness))))) (, ,) (NP (PRP I)) (VP (MD will) (VP (VB make) (S (ADJP (JJ grammatical)))))))))) (. .))',
#   'pos_tags': ['PRON',
#    'VERB',
#    'ADP',
#    'ADJ',
#    'CCONJ',
#    'ADJ',
#    'CCONJ',
#    'ADV',
#    'ADJ',
#    'PROPN',
#    'PUNCT',
#    'DET',
#    'PUNCT',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'VERB',
#    'ADJ',
#    'PUNCT']},
#  'He had neither money nor position -- nothing but his beauty and strength and energy -- so my father forbade the match .': {'parse_string': '(S (S (NP (PRP He)) (VP (VBD had) (NP (NP (DT neither) (NN money) (CC nor) (NN position)) (PRN (: --) (NP (NP (NN nothing)) (CC but) (NP (PRP$ his) (NN beauty) (CC and) (NN strength) (CC and) (NN energy))) (: --))))) (RB so) (S (NP (PRP$ my) (NN father)) (VP (VBD forbade) (NP (DT the) (NN match)))) (. .))',
#   'pos_tags': ['PRON',
#    'AUX',
#    'DET',
#    'NOUN',
#    'CCONJ',
#    'NOUN',
#    'PUNCT',
#    'PRON',
#    'CCONJ',
#    'DET',
#    'NOUN',
#    'CCONJ',
#    'NOUN',
#    'CCONJ',
#    'NOUN',
#    'PUNCT',
#    'ADV',
#    'DET',
#    'NOUN',
#    'VERB',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  'Yet I was aware that Gennaro was no more happy than I was in his presence .': {'parse_string': '(S (CC Yet) (NP (PRP I)) (VP (VBD was) (ADJP (JJ aware) (SBAR (IN that) (S (NP (NNP Gennaro)) (VP (VBD was) (ADJP (ADJP (DT no) (RBR more) (JJ happy)) (SBAR (IN than) (S (NP (PRP I)) (VP (VBD was) (PP (IN in) (NP (PRP$ his) (NN presence)))))))))))) (. .))',
#   'pos_tags': ['CCONJ',
#    'PRON',
#    'AUX',
#    'ADJ',
#    'SCONJ',
#    'PROPN',
#    'AUX',
#    'DET',
#    'ADV',
#    'ADJ',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  'Gennaro said nothing , but I , who knew him so well , could read in his face some emotion which I had never seen there before .': {'parse_string': '(S (S (NP (NNP Gennaro)) (VP (VBD said) (NP (NN nothing)))) (, ,) (CC but) (S (NP (NP (PRP I)) (, ,) (SBAR (WHNP (WP who)) (S (VP (VBD knew) (NP (PRP him)) (ADVP (RB so) (RB well))))) (, ,)) (VP (MD could) (VP (VB read) (PP (IN in) (NP (PRP$ his) (NN face))) (NP (NP (DT some) (NN emotion)) (SBAR (WHNP (WDT which)) (S (NP (PRP I)) (VP (VBD had) (ADVP (RB never)) (VP (VBN seen) (ADVP (RB there)) (ADVP (RB before)))))))))) (. .))',
#   'pos_tags': ['PROPN',
#    'VERB',
#    'PRON',
#    'PUNCT',
#    'CCONJ',
#    'PRON',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'PRON',
#    'ADV',
#    'ADV',
#    'PUNCT',
#    'VERB',
#    'VERB',
#    'ADP',
#    'DET',
#    'NOUN',
#    'DET',
#    'NOUN',
#    'DET',
#    'PRON',
#    'AUX',
#    'ADV',
#    'VERB',
#    'ADV',
#    'ADV',
#    'PUNCT']},
#  'At first I thought that it was dislike .': {'parse_string': '(S (PP (IN At) (NP (RB first))) (NP (PRP I)) (VP (VBD thought) (SBAR (IN that) (S (NP (PRP it)) (VP (VBD was) (NP (JJ dislike)))))) (. .))',
#   'pos_tags': ['ADP',
#    'ADV',
#    'PRON',
#    'VERB',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'ADJ',
#    'PUNCT']},
#  'And then , gradually , I understood that it was more than dislike .': {'parse_string': '(S (CC And) (ADVP (RB then)) (, ,) (ADVP (RB gradually)) (, ,) (NP (PRP I)) (VP (VBD understood) (SBAR (IN that) (S (NP (PRP it)) (VP (VBD was) (ADJP (ADJP (JJR more)) (SBAR (IN than) (S (VP (VB dislike))))))))) (. .))',
#   'pos_tags': ['CCONJ',
#    'ADV',
#    'PUNCT',
#    'ADV',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'ADJ',
#    'SCONJ',
#    'VERB',
#    'PUNCT']},
#  'That night -- the night that I read his terror -- I put my arms round him and I implored him by his love for me and by all that he held dear to hold nothing from me , and to tell me why this huge man overshadowed him so .': {'parse_string': '(S (NP (DT That) (NN night)) (: --) (NP (NP (DT the) (NN night)) (SBAR (WHADVP (WDT that)) (S (NP (PRP I)) (VP (VBD read) (NP (PRP$ his) (NN terror)))))) (: --) (NP (PRP I)) (VP (VBD put) (NP (PRP$ my) (NNS arms)) (PP (IN round) (NP (PRP him)))))',
#   'pos_tags': ['DET',
#    'NOUN',
#    'PUNCT',
#    'DET',
#    'NOUN',
#    'DET',
#    'PRON',
#    'VERB',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PRON',
#    'CCONJ',
#    'PRON',
#    'VERB',
#    'PRON',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PRON',
#    'CCONJ',
#    'ADP',
#    'DET',
#    'DET',
#    'PRON',
#    'VERB',
#    'ADJ',
#    'PART',
#    'VERB',
#    'PRON',
#    'ADP',
#    'PRON',
#    'PUNCT',
#    'CCONJ',
#    'PART',
#    'VERB',
#    'PRON',
#    'ADV',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'PRON',
#    'ADV',
#    'PUNCT']},
#  'The oaths and secrets of this brotherhood were frightful , but once within its rule no escape was possible .': {'parse_string': '(S (S (NP (NP (DT The) (NNS oaths) (CC and) (NNS secrets)) (PP (IN of) (NP (DT this) (NN brotherhood)))) (VP (VBD were) (ADJP (JJ frightful)))) (, ,) (CC but) (S (ADVP (RB once)) (PP (IN within) (NP (PRP$ its) (NN rule))) (NP (DT no) (NN escape)) (VP (VBD was) (ADJP (JJ possible)))) (. .))',
#   'pos_tags': ['DET',
#    'NOUN',
#    'CCONJ',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'AUX',
#    'ADJ',
#    'PUNCT',
#    'CCONJ',
#    'ADV',
#    'ADP',
#    'DET',
#    'NOUN',
#    'DET',
#    'NOUN',
#    'AUX',
#    'ADJ',
#    'PUNCT']},
#  'Gennaro had not yet returned when he came .': {'parse_string': '(S (NP (NNP Gennaro)) (VP (VBD had) (ADVP (RB not) (RB yet)) (VP (VBN returned) (SBAR (WHADVP (WRB when)) (S (NP (PRP he)) (VP (VBD came)))))) (. .))',
#   'pos_tags': ['PROPN',
#    'AUX',
#    'PART',
#    'ADV',
#    'VERB',
#    'ADV',
#    'PRON',
#    'VERB',
#    'PUNCT']},
#  'He struck Gennaro senseless and fled from the house which he was never more to enter .': {'parse_string': '(S (NP (PRP He)) (VP (VP (VBD struck) (NP (NNP Gennaro)) (ADVP (NN senseless))) (CC and) (VP (VBD fled) (PP (IN from) (NP (NP (DT the) (NN house)) (SBAR (WHNP (WDT which)) (S (NP (PRP he)) (VP (VBD was) (ADVP (RB never)) (NP (NP (JJR more)) (SBAR (S (VP (TO to) (VP (VB enter))))))))))))) (. .))',
#   'pos_tags': ['PRON',
#    'VERB',
#    'PROPN',
#    'NOUN',
#    'CCONJ',
#    'VERB',
#    'ADP',
#    'DET',
#    'NOUN',
#    'DET',
#    'PRON',
#    'AUX',
#    'ADV',
#    'ADJ',
#    'PART',
#    'VERB',
#    'PUNCT']},
#  'By midday my husband and I were on our way to London , but not before he had given our benefactor full warning of this danger , and had also left such information for the police as would safeguard his life for the future .': {'parse_string': '(S (PP (IN By) (NP (NN midday))) (NP (NP (PRP$ my) (NN husband)) (CC and) (NP (PRP I))) (VP (VP (VBD were) (PP (IN on) (NP (NP (PRP$ our) (NN way)) (PP (IN to) (NP (NNP London)))))) (, ,) (CC but) (SBAR (RB not) (IN before) (S (NP (PRP he)) (VP (VP (VBD had) (VP (VBN given) (NP (PRP$ our) (NN benefactor)) (NP (NP (JJ full) (NN warning)) (PP (IN of) (NP (DT this) (NN danger)))))) (, ,) (CC and) (VP (VBD had) (ADVP (RB also)) (VP (VBN left) (NP (JJ such) (NN information)) (PP (IN for) (NP (DT the) (NN police))) (SBAR (IN as) (S (VP (MD would) (VP (VB safeguard) (NP (NP (PRP$ his) (NN life)) (PP (IN for) (NP (DT the) (NN future)))))))))))))) (. .))',
#   'pos_tags': ['ADP',
#    'NOUN',
#    'DET',
#    'NOUN',
#    'CCONJ',
#    'PRON',
#    'AUX',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PUNCT',
#    'CCONJ',
#    'PART',
#    'ADP',
#    'PRON',
#    'AUX',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'AUX',
#    'ADV',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'SCONJ',
#    'VERB',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT']},
#  'My darling made use of the few clear days which our start had given us in arranging for a refuge for me in such a fashion that no possible danger could reach me .': {'parse_string': '(S (NP (PRP$ My) (NN darling)) (VP (VBD made) (NP (NN use)) (PP (IN of) (NP (NP (DT the) (JJ few) (JJ clear) (NNS days)) (SBAR (WHNP (WDT which)) (S (S (NP (PRP$ our) (NN start)) (VP (VBD had) (VP (VBN given) (NP (PRP us))))) (PP (IN in) (S (VP (VBG arranging) (PP (IN for) (NP (NP (DT a) (NN refuge)) (PP (IN for) (NP (PRP me))) (PP (IN in) (NP (NP (PDT such) (DT a) (NN fashion)) (SBAR (WDT that) (S (NP (DT no) (JJ possible) (NN danger)) (VP (MD could) (VP (VB reach) (NP (PRP me)))))))))))))))))) (. .))',
#   'pos_tags': ['DET',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'ADP',
#    'DET',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'DET',
#    'DET',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'PRON',
#    'ADP',
#    'VERB',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PRON',
#    'ADP',
#    'DET',
#    'DET',
#    'NOUN',
#    'DET',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'VERB',
#    'PRON',
#    'PUNCT']},
#  'I do not myself know where he lived , or how .': {'parse_string': '(S (NP (PRP I)) (VP (VBP do) (RB not) (NP (PRP myself)) (VP (VB know) (SBAR (SBAR (WHADVP (WRB where)) (S (NP (PRP he)) (VP (VBD lived)))) (, ,) (CC or) (FRAG (WHADVP (WRB how)))))) (. .))',
#   'pos_tags': ['PRON',
#    'AUX',
#    'PART',
#    'PRON',
#    'VERB',
#    'ADV',
#    'PRON',
#    'VERB',
#    'PUNCT',
#    'CCONJ',
#    'ADV',
#    'PUNCT']},
#  "` ` Well , Mr. Gregson , '' said the American , looking across at the official , ` ` I do n't know what your British point of view may be , but I guess that in New York this lady 's husband will receive a pretty general vote of thanks . ''": {'parse_string': "(SINV (`` `) (`` `) (INTJ (UH Well)) (, ,) (NP (NNP Mr.) (NNP Gregson)) (, ,) ('' '') (VP (VBD said)) (NP (DT the) (NNP American)) (, ,) (VBG looking) (ADVP (RB across)) (PP (IN at) (NP (DT the) (NN official))) (, ,) ('' `))",
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'INTJ',
#    'PUNCT',
#    'PROPN',
#    'PROPN',
#    'PUNCT',
#    'PUNCT',
#    'VERB',
#    'DET',
#    'PROPN',
#    'PUNCT',
#    'VERB',
#    'ADV',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'PRON',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'VERB',
#    'AUX',
#    'PUNCT',
#    'CCONJ',
#    'PRON',
#    'VERB',
#    'SCONJ',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'DET',
#    'NOUN',
#    'PART',
#    'NOUN',
#    'VERB',
#    'VERB',
#    'DET',
#    'ADV',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'PUNCT',
#    'PUNCT']},
#  '` ` If what she says is corroborated , I do not think she or her husband has much to fear .': {'parse_string': '(S (`` `) (`` `) (SBAR (IN If) (S (SBAR (WHNP (WP what)) (S (NP (PRP she)) (VP (VBZ says)))) (VP (VBZ is) (VP (VBN corroborated))))) (, ,) (NP (PRP I)) (VP (VBP do) (RB not) (VP (VB think) (SBAR (S (NP (NP (PRP she)) (CC or) (NP (PRP$ her) (NN husband))) (VP (VBZ has) (NP (NP (JJ much)) (SBAR (S (VP (TO to) (VP (VB fear))))))))))) (. .))',
#   'pos_tags': ['PUNCT',
#    'PUNCT',
#    'SCONJ',
#    'PRON',
#    'PRON',
#    'VERB',
#    'AUX',
#    'VERB',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'PRON',
#    'CCONJ',
#    'DET',
#    'NOUN',
#    'AUX',
#    'ADJ',
#    'PART',
#    'VERB',
#    'PUNCT']},
#  "But what I ca n't make head or tail of , Mr. Holmes , is how on earth YOU got yourself mixed up in the matter . ''": {'parse_string': "(S (CC But) (SBAR (WHNP (WP what)) (S (NP (PRP I)) (VP (MD ca) (RB n't) (VP (VB make) (NP (NP (NN head) (CC or) (NN tail)) (PP (IN of))))))) (, ,) (NP (NNP Mr.) (NNP Holmes)) (, ,) (VP (VBZ is) (SBAR (WHADVP (WRB how)) (S (PP (IN on) (NP (NN earth))) (NP (PRP YOU)) (VP (VBD got) (S (NP (PRP yourself)) (ADJP (VBN mixed) (RP up) (PP (IN in) (NP (DT the) (NN matter))))))))) (. .) ('' ''))",
#   'pos_tags': ['CCONJ',
#    'PRON',
#    'PRON',
#    'VERB',
#    'PART',
#    'VERB',
#    'NOUN',
#    'CCONJ',
#    'NOUN',
#    'ADP',
#    'PUNCT',
#    'PROPN',
#    'PROPN',
#    'PUNCT',
#    'AUX',
#    'ADV',
#    'ADP',
#    'NOUN',
#    'PRON',
#    'VERB',
#    'PRON',
#    'VERB',
#    'ADP',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'PUNCT']},
#  "By the way , it is not eight o'clock , and a Wagner night at Covent Garden !": {'parse_string': "(S (PP (IN By) (NP (DT the) (NN way))) (, ,) (NP (PRP it)) (VP (VBZ is) (RB not) (NP (CD eight) (NN o'clock)) (, ,) (CC and) (NP (NP (DT a) (NNP Wagner) (NN night)) (PP (IN at) (NP (NNP Covent) (NNP Garden))))) (. !))",
#   'pos_tags': ['ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'PRON',
#    'AUX',
#    'PART',
#    'NUM',
#    'NOUN',
#    'PUNCT',
#    'CCONJ',
#    'DET',
#    'PROPN',
#    'NOUN',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'PUNCT']}}

# %%
text = "`` Know then that in the time of the Great Rebellion ( the history of which by the learned Lord Clarendon I most earnestly commend to your attention ) this Manor of Baskerville was held by Hugo of that name , nor can it be gainsaid that he was a most wild , profane , and godless man ."
doc = nlp(text)
sent = list(doc.sents)[0]
print(sent._.parse_string)
# Out:
# (S (`` ``) (VB Know) (ADVP (RB then)) (SBAR (IN that) (S (IN in) (NP (NP (NP (DT the) (NN time)) (PP (IN of) (NP (DT the) (NNP Great) (NNP Rebellion)))) (PRN (-LRB- -LRB-) (NP (NP (DT the) (NN history)) (SBAR (WHPP (IN of) (WHNP (WDT which))) (S (PP (IN by) (NP (DT the) (VBN learned) (NNP Lord) (NNP Clarendon))) (NP (PRP I)) (VP (ADVP (RBS most) (RB earnestly)) (VBP commend) (PP (IN to) (NP (PRP$ your) (NN attention))))))) (-RRB- -RRB-))))))

# %%
list(doc.sents)[1]
# Out:
# this Manor of Baskerville was held by Hugo of that name , nor can it be gainsaid that he was a most wild , profane , and godless man .
